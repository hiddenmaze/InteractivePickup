# %% [markdown]
# ## Import Dependencies

# %%
from os.path import isfile, join
import numpy as np
from utils import HGN_organize_data, HGN_divide_train_test
from code_HGN_train import train
from preprocess4HGN import preprocess

# %% [markdown]
# ## Load Preprocessed Data

# %%
if isfile('./data/preprocessed4HGN.npz') == False:
    preprocess()
    
npzfile = np.load('./data/preprocessed4HGN.npz')

img_idx = npzfile['arr_0']
sen_len = npzfile['arr_1']
text_inputs = npzfile['arr_2']
pos_outputs = npzfile['arr_3']

print 'End loading MetaData'
# Out:
# End loading MetaData

# %% [markdown]
# ## Load data and divide training and test set

# %%
num_data = img_idx.shape[0]
dim_sentence = text_inputs.shape[1]
max_step_sentence = text_inputs.shape[2]

img_path = './data/train_img'
script_path = './data/train_heatmap'

total_images, total_heatmaps = HGN_organize_data(img_path, script_path);

idx_train, idx_test, num_train, num_test, \
train_img_idx, train_sen_len, train_text_inputs, train_pos_outputs, \
test_img_idx, test_sen_len, test_text_inputs, test_pos_outputs = \
HGN_divide_train_test(img_idx, sen_len, text_inputs, pos_outputs, num_data=num_data)
# Out:
# /usr/local/lib/python2.7/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Test image index : [127 422  15 390  19 235 138 338  31 318 378 270 465 277  26  76 124 195
#  111 445 367 189  66]
# Ended divided training and test dataset. Training : 19355, Test : 994

# %% [markdown]
# ## Start Training

# %%
train(img_resize = 256, # must be fixed
      heatmap_resize = 64, # must be fixed
      dim_sentence = dim_sentence,
      max_step_sentence = max_step_sentence,
      batch_size = 8, 
      max_epoch = 300,
      num_train = num_train,
      save_stride = 10,
      num_hg_Depth = 4, # good be fixed
      dim_hg_feat = 256, # good be fixed
      dim_rnn_cell = 256, # good be fixed
      restore_flag = 0,
      restore_path = '',
      restore_epoch = 0,
      total_images = total_images,
      total_heatmaps = total_heatmaps,
      train_text_inputs = train_text_inputs,
      train_sen_len = train_sen_len,
      train_img_idx = train_img_idx,
      train_pos_outputs = train_pos_outputs,
      learning_rate = 0.00001) # good be fixed
# Out:
# Now ready to start the session.
# batch loss : 0.0411909 -> about 5427.975 second left to finish this epoch
# batch loss : 0.0185834 -> about 457.861 second left to finish this epoch
# batch loss : 0.0202038 -> about 415.988 second left to finish this epoch
# batch loss : 0.0180969 -> about 390.180 second left to finish this epoch
# batch loss : 0.0202712 -> about 368.268 second left to finish this epoch
# batch loss : 0.0195459 -> about 348.313 second left to finish this epoch
# batch loss : 0.0165712 -> about 328.878 second left to finish this epoch
# batch loss : 0.0190475 -> about 309.755 second left to finish this epoch
# batch loss : 0.0198531 -> about 291.177 second left to finish this epoch
# batch loss : 0.0185292 -> about 272.564 second left to finish this epoch
# batch loss : 0.0194838 -> about 254.310 second left to finish this epoch
# batch loss : 0.0169322 -> about 236.128 second left to finish this epoch
# batch loss : 0.0169373 -> about 218.096 second left to finish this epoch
# batch loss : 0.0184498 -> about 200.011 second left to finish this epoch
# batch loss : 0.0176636 -> about 181.984 second left to finish this epoch
# batch loss : 0.0157414 -> about 164.082 second left to finish this epoch
# batch loss : 0.0179611 -> about 146.154 second left to finish this epoch
# batch loss : 0.0158272 -> about 128.264 second left to finish this epoch
# batch loss : 0.013363 -> about 110.388 second left to finish this epoch
# batch loss : 0.0150387 -> about 92.602 second left to finish this epoch
# batch loss : 0.0161806 -> about 74.774 second left to finish this epoch
# batch loss : 0.0132758 -> about 56.941 second left to finish this epoch
# batch loss : 0.0145348 -> about 39.094 second left to finish this epoch
# batch loss : 0.0141863 -> about 21.244 second left to finish this epoch
# batch loss : 0.015063 -> about 3.392 second left to finish this epoch
# ('current epoch : 1', ', current train loss : 0.0168564528944')
# batch loss : 0.00908763 -> about 390.559 second left to finish this epoch
# batch loss : 0.0108542 -> about 414.831 second left to finish this epoch
# batch loss : 0.0116384 -> about 396.875 second left to finish this epoch
# batch loss : 0.00991869 -> about 379.010 second left to finish this epoch
# batch loss : 0.00736465 -> about 361.131 second left to finish this epoch
# batch loss : 0.0101547 -> about 343.747 second left to finish this epoch
# batch loss : 0.0116553 -> about 325.619 second left to finish this epoch
# batch loss : 0.00812123 -> about 307.856 second left to finish this epoch
# batch loss : 0.0115251 -> about 289.852 second left to finish this epoch
# batch loss : 0.00688095 -> about 272.060 second left to finish this epoch
# batch loss : 0.0107778 -> about 254.158 second left to finish this epoch
# batch loss : 0.0143148 -> about 236.191 second left to finish this epoch
# batch loss : 0.00753481 -> about 218.364 second left to finish this epoch
# batch loss : 0.00775736 -> about 200.433 second left to finish this epoch
# batch loss : 0.0121331 -> about 182.569 second left to finish this epoch
# batch loss : 0.00640102 -> about 164.638 second left to finish this epoch
# batch loss : 0.011226 -> about 146.757 second left to finish this epoch
# batch loss : 0.00915816 -> about 128.782 second left to finish this epoch
# batch loss : 0.0108068 -> about 110.852 second left to finish this epoch
# batch loss : 0.00893191 -> about 93.013 second left to finish this epoch
# batch loss : 0.0115351 -> about 75.085 second left to finish this epoch
# batch loss : 0.00559587 -> about 57.190 second left to finish this epoch
# batch loss : 0.00863136 -> about 39.247 second left to finish this epoch
# batch loss : 0.0120896 -> about 21.335 second left to finish this epoch
# batch loss : 0.0132952 -> about 3.405 second left to finish this epoch
# ('current epoch : 2', ', current train loss : 0.0100005520942')
# batch loss : 0.00822931 -> about 461.170 second left to finish this epoch
# batch loss : 0.00946392 -> about 412.758 second left to finish this epoch
# batch loss : 0.00757765 -> about 394.157 second left to finish this epoch
# batch loss : 0.0128062 -> about 376.383 second left to finish this epoch
# batch loss : 0.00746961 -> about 358.720 second left to finish this epoch
# batch loss : 0.00686637 -> about 340.817 second left to finish this epoch
# batch loss : 0.0110838 -> about 323.118 second left to finish this epoch
# batch loss : 0.00812752 -> about 305.461 second left to finish this epoch
# batch loss : 0.00666441 -> about 288.087 second left to finish this epoch
# batch loss : 0.00839234 -> about 270.267 second left to finish this epoch
# batch loss : 0.00399605 -> about 252.370 second left to finish this epoch
# batch loss : 0.00760278 -> about 234.587 second left to finish this epoch
# batch loss : 0.0141025 -> about 216.862 second left to finish this epoch
# batch loss : 0.0114804 -> about 199.036 second left to finish this epoch
# batch loss : 0.00314133 -> about 181.224 second left to finish this epoch
# batch loss : 0.00612635 -> about 163.397 second left to finish this epoch
# batch loss : 0.0103608 -> about 145.610 second left to finish this epoch
# batch loss : 0.0113725 -> about 127.848 second left to finish this epoch
# batch loss : 0.00747987 -> about 110.052 second left to finish this epoch
# batch loss : 0.00338326 -> about 92.261 second left to finish this epoch
# batch loss : 0.0152913 -> about 74.472 second left to finish this epoch
# batch loss : 0.0114579 -> about 56.695 second left to finish this epoch
# batch loss : 0.0119605 -> about 38.920 second left to finish this epoch
# batch loss : 0.00736603 -> about 21.147 second left to finish this epoch
# batch loss : 0.00619601 -> about 3.377 second left to finish this epoch
# ('current epoch : 3', ', current train loss : 0.00850813599029')
# batch loss : 0.0116892 -> about 432.587 second left to finish this epoch
# batch loss : 0.00434523 -> about 411.226 second left to finish this epoch
# batch loss : 0.012223 -> about 394.567 second left to finish this epoch
# batch loss : 0.00540909 -> about 376.339 second left to finish this epoch
# batch loss : 0.00762091 -> about 358.841 second left to finish this epoch
# batch loss : 0.0115002 -> about 341.212 second left to finish this epoch
# batch loss : 0.00388321 -> about 323.199 second left to finish this epoch
# batch loss : 0.00897771 -> about 305.331 second left to finish this epoch
# batch loss : 0.00767129 -> about 287.328 second left to finish this epoch
# batch loss : 0.00960129 -> about 269.748 second left to finish this epoch
# batch loss : 0.00491812 -> about 251.961 second left to finish this epoch
# batch loss : 0.0079262 -> about 234.134 second left to finish this epoch
# batch loss : 0.00817035 -> about 216.445 second left to finish this epoch
# batch loss : 0.00896337 -> about 198.660 second left to finish this epoch
# batch loss : 0.00669169 -> about 180.933 second left to finish this epoch
# batch loss : 0.00953664 -> about 163.179 second left to finish this epoch
# batch loss : 0.00885942 -> about 145.406 second left to finish this epoch
# batch loss : 0.00825981 -> about 127.662 second left to finish this epoch
# batch loss : 0.00692971 -> about 109.908 second left to finish this epoch
# batch loss : 0.00833506 -> about 92.159 second left to finish this epoch
# batch loss : 0.00897205 -> about 74.402 second left to finish this epoch
# batch loss : 0.0105785 -> about 56.635 second left to finish this epoch
# batch loss : 0.0107511 -> about 38.887 second left to finish this epoch
# batch loss : 0.0120314 -> about 21.130 second left to finish this epoch
# batch loss : 0.00594453 -> about 3.375 second left to finish this epoch
# ('current epoch : 4', ', current train loss : 0.00788624369617')
# batch loss : 0.00623734 -> about 395.226 second left to finish this epoch
# batch loss : 0.00950267 -> about 410.855 second left to finish this epoch
# batch loss : 0.00493647 -> about 394.436 second left to finish this epoch
# batch loss : 0.00945855 -> about 376.617 second left to finish this epoch
# batch loss : 0.00961809 -> about 358.737 second left to finish this epoch
# batch loss : 0.00891163 -> about 340.934 second left to finish this epoch
# batch loss : 0.00611391 -> about 323.061 second left to finish this epoch
# batch loss : 0.0113286 -> about 305.370 second left to finish this epoch
# batch loss : 0.0060431 -> about 287.662 second left to finish this epoch
# batch loss : 0.00339873 -> about 269.909 second left to finish this epoch
# batch loss : 0.00431055 -> about 252.116 second left to finish this epoch
# batch loss : 0.0141158 -> about 234.335 second left to finish this epoch
# batch loss : 0.00485154 -> about 216.567 second left to finish this epoch
# batch loss : 0.00604522 -> about 198.793 second left to finish this epoch
# batch loss : 0.00579137 -> about 180.999 second left to finish this epoch
# batch loss : 0.00433577 -> about 163.219 second left to finish this epoch
# batch loss : 0.00534647 -> about 145.488 second left to finish this epoch
# batch loss : 0.00464767 -> about 127.728 second left to finish this epoch
# batch loss : 0.00981156 -> about 109.985 second left to finish this epoch
# batch loss : 0.0102914 -> about 92.219 second left to finish this epoch
# batch loss : 0.00917304 -> about 74.461 second left to finish this epoch
# batch loss : 0.0059264 -> about 56.678 second left to finish this epoch
# batch loss : 0.00428973 -> about 38.916 second left to finish this epoch
# batch loss : 0.0109874 -> about 21.143 second left to finish this epoch
# batch loss : 0.0103464 -> about 3.376 second left to finish this epoch
# ('current epoch : 5', ', current train loss : 0.00748528701711')
# batch loss : 0.00529429 -> about 414.075 second left to finish this epoch
# batch loss : 0.00961397 -> about 411.561 second left to finish this epoch
# batch loss : 0.00956765 -> about 393.102 second left to finish this epoch
# batch loss : 0.00362396 -> about 375.662 second left to finish this epoch
# batch loss : 0.00496275 -> about 357.865 second left to finish this epoch
# batch loss : 0.00634619 -> about 340.258 second left to finish this epoch
# batch loss : 0.00465979 -> about 322.505 second left to finish this epoch
# batch loss : 0.00756212 -> about 304.759 second left to finish this epoch
# batch loss : 0.0123551 -> about 287.257 second left to finish this epoch
# batch loss : 0.00303108 -> about 269.398 second left to finish this epoch
# batch loss : 0.00596241 -> about 251.681 second left to finish this epoch
# batch loss : 0.00564709 -> about 234.021 second left to finish this epoch
# batch loss : 0.0109333 -> about 216.303 second left to finish this epoch
# batch loss : 0.0044101 -> about 198.565 second left to finish this epoch
# batch loss : 0.00516337 -> about 180.839 second left to finish this epoch
# batch loss : 0.0029487 -> about 163.078 second left to finish this epoch
# batch loss : 0.00457198 -> about 145.366 second left to finish this epoch
# batch loss : 0.00777958 -> about 127.645 second left to finish this epoch
# batch loss : 0.00767638 -> about 109.887 second left to finish this epoch
# batch loss : 0.0100041 -> about 92.207 second left to finish this epoch
# batch loss : 0.00841483 -> about 74.444 second left to finish this epoch
# batch loss : 0.0085376 -> about 56.691 second left to finish this epoch
# batch loss : 0.00274422 -> about 38.914 second left to finish this epoch
# batch loss : 0.00538867 -> about 21.145 second left to finish this epoch
# batch loss : 0.00783419 -> about 3.376 second left to finish this epoch
# ('current epoch : 6', ', current train loss : 0.00715833740383')
# batch loss : 0.00856066 -> about 466.311 second left to finish this epoch
# batch loss : 0.00811263 -> about 411.846 second left to finish this epoch
# batch loss : 0.00367317 -> about 394.059 second left to finish this epoch
# batch loss : 0.00770864 -> about 376.266 second left to finish this epoch
# batch loss : 0.00286497 -> about 358.820 second left to finish this epoch
# batch loss : 0.0119656 -> about 340.767 second left to finish this epoch
# batch loss : 0.00336721 -> about 322.948 second left to finish this epoch
# batch loss : 0.0145291 -> about 305.182 second left to finish this epoch
# batch loss : 0.00316676 -> about 287.408 second left to finish this epoch
# batch loss : 0.00398622 -> about 269.660 second left to finish this epoch
# batch loss : 0.00792145 -> about 251.876 second left to finish this epoch
# batch loss : 0.0129592 -> about 234.184 second left to finish this epoch
# batch loss : 0.0104734 -> about 216.490 second left to finish this epoch
# batch loss : 0.008096 -> about 198.692 second left to finish this epoch
# batch loss : 0.0111536 -> about 180.941 second left to finish this epoch
# batch loss : 0.00346644 -> about 163.144 second left to finish this epoch
# batch loss : 0.00523805 -> about 145.412 second left to finish this epoch
# batch loss : 0.00928174 -> about 127.630 second left to finish this epoch
# batch loss : 0.00864481 -> about 109.900 second left to finish this epoch
# batch loss : 0.00818198 -> about 92.235 second left to finish this epoch
# batch loss : 0.00612541 -> about 74.464 second left to finish this epoch
# batch loss : 0.0059179 -> about 56.700 second left to finish this epoch
# batch loss : 0.00776529 -> about 38.931 second left to finish this epoch
# batch loss : 0.00605766 -> about 21.159 second left to finish this epoch
# batch loss : 0.00704655 -> about 3.379 second left to finish this epoch
# ('current epoch : 7', ', current train loss : 0.00687317737417')
# batch loss : 0.00604955 -> about 419.200 second left to finish this epoch
# batch loss : 0.00365126 -> about 413.364 second left to finish this epoch
# batch loss : 0.0124606 -> about 395.496 second left to finish this epoch
# batch loss : 0.0086115 -> about 377.229 second left to finish this epoch
# batch loss : 0.0094856 -> about 359.122 second left to finish this epoch
# batch loss : 0.00337338 -> about 341.164 second left to finish this epoch
# batch loss : 0.00693716 -> about 323.159 second left to finish this epoch
# batch loss : 0.0105275 -> about 305.443 second left to finish this epoch
# batch loss : 0.00464843 -> about 287.620 second left to finish this epoch
# batch loss : 0.00890776 -> about 269.836 second left to finish this epoch
# batch loss : 0.00531575 -> about 252.042 second left to finish this epoch
# batch loss : 0.00944692 -> about 234.568 second left to finish this epoch
# batch loss : 0.0157071 -> about 216.912 second left to finish this epoch
# batch loss : 0.00471462 -> about 199.100 second left to finish this epoch
# batch loss : 0.00968621 -> about 181.292 second left to finish this epoch
# batch loss : 0.00671062 -> about 163.490 second left to finish this epoch
# batch loss : 0.00380414 -> about 145.689 second left to finish this epoch
# batch loss : 0.0060762 -> about 127.891 second left to finish this epoch
# batch loss : 0.00859234 -> about 110.107 second left to finish this epoch
# batch loss : 0.0068066 -> about 92.309 second left to finish this epoch
# batch loss : 0.00973525 -> about 74.514 second left to finish this epoch
# batch loss : 0.00817517 -> about 56.733 second left to finish this epoch
# batch loss : 0.00610491 -> about 38.944 second left to finish this epoch
# batch loss : 0.00134695 -> about 21.159 second left to finish this epoch
# batch loss : 0.00949497 -> about 3.378 second left to finish this epoch
# ('current epoch : 8', ', current train loss : 0.00656989115195')
# batch loss : 0.00414936 -> about 471.388 second left to finish this epoch
# batch loss : 0.00851407 -> about 413.008 second left to finish this epoch
# batch loss : 0.00979762 -> about 394.883 second left to finish this epoch
# batch loss : 0.00891595 -> about 377.146 second left to finish this epoch
# batch loss : 0.00671847 -> about 359.727 second left to finish this epoch
# batch loss : 0.00546016 -> about 341.841 second left to finish this epoch
# batch loss : 0.0106854 -> about 323.793 second left to finish this epoch
# batch loss : 0.00293512 -> about 305.990 second left to finish this epoch
# batch loss : 0.00920059 -> about 288.112 second left to finish this epoch
# batch loss : 0.00801947 -> about 270.834 second left to finish this epoch
# batch loss : 0.00250621 -> about 253.126 second left to finish this epoch
# batch loss : 0.0096482 -> about 235.301 second left to finish this epoch
# batch loss : 0.00308782 -> about 217.548 second left to finish this epoch
# batch loss : 0.00724788 -> about 199.645 second left to finish this epoch
# batch loss : 0.00611829 -> about 181.882 second left to finish this epoch
# batch loss : 0.00482491 -> about 164.052 second left to finish this epoch
# batch loss : 0.0042252 -> about 146.247 second left to finish this epoch
# batch loss : 0.00840403 -> about 128.414 second left to finish this epoch
# batch loss : 0.00652264 -> about 110.569 second left to finish this epoch
# batch loss : 0.0146243 -> about 92.713 second left to finish this epoch
# batch loss : 0.00636694 -> about 74.855 second left to finish this epoch
# batch loss : 0.0104167 -> about 56.990 second left to finish this epoch
# batch loss : 0.00180481 -> about 39.123 second left to finish this epoch
# batch loss : 0.00365818 -> about 21.261 second left to finish this epoch
# batch loss : 0.00332098 -> about 3.394 second left to finish this epoch
# ('current epoch : 9', ', current train loss : 0.00625545213552')
# batch loss : 0.00513208 -> about 468.817 second left to finish this epoch
# batch loss : 0.00850351 -> about 415.563 second left to finish this epoch
# batch loss : 0.00265272 -> about 398.069 second left to finish this epoch
# batch loss : 0.00641784 -> about 380.257 second left to finish this epoch
# batch loss : 0.00529193 -> about 362.098 second left to finish this epoch
# batch loss : 0.0032576 -> about 344.114 second left to finish this epoch
# batch loss : 0.00708815 -> about 325.865 second left to finish this epoch
# batch loss : 0.00323239 -> about 307.941 second left to finish this epoch
# batch loss : 0.0050508 -> about 290.603 second left to finish this epoch
# batch loss : 0.00265996 -> about 272.924 second left to finish this epoch
# batch loss : 0.00691273 -> about 254.884 second left to finish this epoch
# batch loss : 0.00757114 -> about 236.966 second left to finish this epoch
# batch loss : 0.00529469 -> about 219.099 second left to finish this epoch
# batch loss : 0.00567676 -> about 201.134 second left to finish this epoch
# batch loss : 0.010375 -> about 183.118 second left to finish this epoch
# batch loss : 0.00695954 -> about 165.070 second left to finish this epoch
# batch loss : 0.0114073 -> about 147.053 second left to finish this epoch
# batch loss : 0.00379767 -> about 129.079 second left to finish this epoch
# batch loss : 0.0024325 -> about 111.113 second left to finish this epoch
# batch loss : 0.00686924 -> about 93.147 second left to finish this epoch
# batch loss : 0.00716178 -> about 75.207 second left to finish this epoch
# batch loss : 0.00663765 -> about 57.252 second left to finish this epoch
# batch loss : 0.00657569 -> about 39.302 second left to finish this epoch
# batch loss : 0.00576352 -> about 21.351 second left to finish this epoch
# batch loss : 0.0029002 -> about 3.409 second left to finish this epoch
# ('current epoch : 10', ', current train loss : 0.00577778933925')
# Model saved in file : ./trained_HGN/model.ckpt-10
# batch loss : 0.0102055 -> about 419.002 second left to finish this epoch
# batch loss : 0.00428434 -> about 413.558 second left to finish this epoch
# batch loss : 0.00565416 -> about 396.489 second left to finish this epoch
# batch loss : 0.00410817 -> about 378.840 second left to finish this epoch
# batch loss : 0.00451542 -> about 361.121 second left to finish this epoch
# batch loss : 0.00674218 -> about 343.662 second left to finish this epoch
# batch loss : 0.00208353 -> about 325.741 second left to finish this epoch
# batch loss : 0.00561373 -> about 307.659 second left to finish this epoch
# batch loss : 0.00837051 -> about 289.584 second left to finish this epoch
# batch loss : 0.00627534 -> about 271.653 second left to finish this epoch
# batch loss : 0.000836689 -> about 253.722 second left to finish this epoch
# batch loss : 0.00277276 -> about 235.862 second left to finish this epoch
# batch loss : 0.00162944 -> about 218.004 second left to finish this epoch
# batch loss : 0.00620011 -> about 200.308 second left to finish this epoch
# batch loss : 0.00654989 -> about 182.433 second left to finish this epoch
# batch loss : 0.00272534 -> about 164.524 second left to finish this epoch
# batch loss : 0.00672563 -> about 146.613 second left to finish this epoch
# batch loss : 0.00566131 -> about 128.684 second left to finish this epoch
# batch loss : 0.00280781 -> about 110.783 second left to finish this epoch
# batch loss : 0.0050431 -> about 92.881 second left to finish this epoch
# batch loss : 0.00648087 -> about 74.985 second left to finish this epoch
# batch loss : 0.00744679 -> about 57.088 second left to finish this epoch
# batch loss : 0.000832434 -> about 39.194 second left to finish this epoch
# batch loss : 0.00811419 -> about 21.298 second left to finish this epoch
# batch loss : 0.00277748 -> about 3.400 second left to finish this epoch
# ('current epoch : 11', ', current train loss : 0.00505049374709')
# batch loss : 0.00506084 -> about 461.298 second left to finish this epoch
# batch loss : 0.00697462 -> about 416.234 second left to finish this epoch
# batch loss : 0.00455253 -> about 396.740 second left to finish this epoch
# batch loss : 0.00318599 -> about 378.620 second left to finish this epoch
# batch loss : 0.0034035 -> about 360.744 second left to finish this epoch
# batch loss : 0.00910414 -> about 342.927 second left to finish this epoch
# batch loss : 0.00137088 -> about 325.277 second left to finish this epoch
# batch loss : 0.00547886 -> about 307.646 second left to finish this epoch
# batch loss : 0.011181 -> about 289.721 second left to finish this epoch
# batch loss : 0.00119714 -> about 271.814 second left to finish this epoch
# batch loss : 0.00371936 -> about 253.869 second left to finish this epoch
# batch loss : 0.00602393 -> about 235.931 second left to finish this epoch
# batch loss : 0.00156963 -> about 218.170 second left to finish this epoch
# batch loss : 0.000987107 -> about 200.294 second left to finish this epoch
# batch loss : 0.00202671 -> about 182.347 second left to finish this epoch
# batch loss : 0.0022054 -> about 164.481 second left to finish this epoch
# batch loss : 0.00456959 -> about 146.610 second left to finish this epoch
# batch loss : 0.00368245 -> about 128.719 second left to finish this epoch
# batch loss : 0.0114075 -> about 110.795 second left to finish this epoch
# batch loss : 0.00209071 -> about 92.897 second left to finish this epoch
# batch loss : 0.00473272 -> about 74.998 second left to finish this epoch
# batch loss : 0.00447189 -> about 57.088 second left to finish this epoch
# batch loss : 0.00325115 -> about 39.191 second left to finish this epoch
# batch loss : 0.00775573 -> about 21.293 second left to finish this epoch
# batch loss : 0.0102066 -> about 3.400 second left to finish this epoch
# ('current epoch : 12', ', current train loss : 0.00428204087243')
# batch loss : 0.00218209 -> about 426.397 second left to finish this epoch
# batch loss : 0.0050793 -> about 412.287 second left to finish this epoch
# batch loss : 0.00395092 -> about 395.347 second left to finish this epoch
# batch loss : 0.00174611 -> about 379.259 second left to finish this epoch
# batch loss : 0.00536135 -> about 358.584 second left to finish this epoch
# batch loss : 0.000474262 -> about 329.680 second left to finish this epoch
# batch loss : 0.00476718 -> about 305.353 second left to finish this epoch
# batch loss : 0.00543244 -> about 283.787 second left to finish this epoch
# batch loss : 0.00586812 -> about 263.911 second left to finish this epoch
# batch loss : 0.00187495 -> about 245.117 second left to finish this epoch
# batch loss : 0.0129244 -> about 227.085 second left to finish this epoch
# batch loss : 0.00317028 -> about 209.702 second left to finish this epoch
# batch loss : 0.00674124 -> about 192.714 second left to finish this epoch
# batch loss : 0.00147386 -> about 176.058 second left to finish this epoch
# batch loss : 0.00510221 -> about 159.665 second left to finish this epoch
# batch loss : 0.00218856 -> about 143.642 second left to finish this epoch
# batch loss : 0.00599435 -> about 127.626 second left to finish this epoch
# batch loss : 0.0042704 -> about 111.744 second left to finish this epoch
# batch loss : 0.00185633 -> about 95.987 second left to finish this epoch
# batch loss : 0.00263259 -> about 80.300 second left to finish this epoch
# batch loss : 0.00687064 -> about 64.716 second left to finish this epoch
# batch loss : 0.00831069 -> about 49.181 second left to finish this epoch
# batch loss : 0.00314581 -> about 34.092 second left to finish this epoch
# batch loss : 0.00230612 -> about 18.858 second left to finish this epoch
# batch loss : 0.00306799 -> about 3.059 second left to finish this epoch
# ('current epoch : 13', ', current train loss : 0.00365014836958')
# batch loss : 0.00153681 -> about 532.361 second left to finish this epoch
# batch loss : 0.00254444 -> about 510.746 second left to finish this epoch
# batch loss : 0.00323756 -> about 489.155 second left to finish this epoch
# batch loss : 0.00167175 -> about 466.711 second left to finish this epoch
# batch loss : 0.0058559 -> about 444.880 second left to finish this epoch
# batch loss : 0.00436605 -> about 423.108 second left to finish this epoch
# batch loss : 0.00356909 -> about 401.310 second left to finish this epoch
# batch loss : 0.00144523 -> about 379.233 second left to finish this epoch
# batch loss : 0.00227549 -> about 357.070 second left to finish this epoch
# batch loss : 0.00879056 -> about 335.050 second left to finish this epoch
# batch loss : 0.00341763 -> about 313.081 second left to finish this epoch
# batch loss : 0.00351238 -> about 291.046 second left to finish this epoch
# batch loss : 0.000932692 -> about 268.903 second left to finish this epoch
# batch loss : 0.000995082 -> about 246.778 second left to finish this epoch
# batch loss : 0.00299653 -> about 224.616 second left to finish this epoch
# batch loss : 0.00468647 -> about 202.495 second left to finish this epoch
# batch loss : 0.00089173 -> about 180.415 second left to finish this epoch
# batch loss : 0.000668208 -> about 158.371 second left to finish this epoch
# batch loss : 0.00848832 -> about 136.307 second left to finish this epoch
# batch loss : 0.00306146 -> about 114.273 second left to finish this epoch
# batch loss : 0.00237996 -> about 92.261 second left to finish this epoch
# batch loss : 0.00152846 -> about 70.236 second left to finish this epoch
# batch loss : 0.00101558 -> about 48.214 second left to finish this epoch
# batch loss : 0.000659641 -> about 26.194 second left to finish this epoch
# batch loss : 0.00176464 -> about 4.183 second left to finish this epoch
# ('current epoch : 14', ', current train loss : 0.00317281135732')
# batch loss : 0.00101475 -> about 518.856 second left to finish this epoch
# batch loss : 0.00375979 -> about 510.761 second left to finish this epoch
# batch loss : 0.00169006 -> about 488.690 second left to finish this epoch
# batch loss : 0.00249335 -> about 465.994 second left to finish this epoch
# batch loss : 0.00398734 -> about 443.828 second left to finish this epoch
# batch loss : 0.00168743 -> about 421.886 second left to finish this epoch
# batch loss : 0.00738654 -> about 399.904 second left to finish this epoch
# batch loss : 0.000855852 -> about 377.965 second left to finish this epoch
# batch loss : 0.00100601 -> about 356.011 second left to finish this epoch
# batch loss : 0.00307766 -> about 334.050 second left to finish this epoch
# batch loss : 0.00094894 -> about 312.035 second left to finish this epoch
# batch loss : 0.00171129 -> about 290.195 second left to finish this epoch
# batch loss : 0.00210606 -> about 268.101 second left to finish this epoch
# batch loss : 0.00106936 -> about 246.195 second left to finish this epoch
# batch loss : 0.00122613 -> about 224.174 second left to finish this epoch
# batch loss : 0.00235766 -> about 202.115 second left to finish this epoch
# batch loss : 0.00700082 -> about 180.171 second left to finish this epoch
# batch loss : 0.00444604 -> about 158.167 second left to finish this epoch
# batch loss : 0.00170119 -> about 136.160 second left to finish this epoch
# batch loss : 0.00309498 -> about 114.225 second left to finish this epoch
# batch loss : 0.00539297 -> about 92.212 second left to finish this epoch
# batch loss : 0.00158938 -> about 70.198 second left to finish this epoch
# batch loss : 0.00319694 -> about 48.196 second left to finish this epoch
# batch loss : 0.00596121 -> about 26.191 second left to finish this epoch
# batch loss : 0.00328418 -> about 4.182 second left to finish this epoch
# ('current epoch : 15', ', current train loss : 0.00276323016711')
# batch loss : 0.00288834 -> about 512.003 second left to finish this epoch
# batch loss : 0.00035688 -> about 509.125 second left to finish this epoch
# batch loss : 0.00587171 -> about 487.245 second left to finish this epoch
# batch loss : 0.00103148 -> about 466.135 second left to finish this epoch
# batch loss : 0.00176161 -> about 445.072 second left to finish this epoch
# batch loss : 0.00255156 -> about 423.254 second left to finish this epoch
# batch loss : 0.000805911 -> about 400.819 second left to finish this epoch
# batch loss : 0.00127438 -> about 378.927 second left to finish this epoch
# batch loss : 0.00482142 -> about 356.834 second left to finish this epoch
# batch loss : 0.00386315 -> about 334.552 second left to finish this epoch
# batch loss : 0.00145114 -> about 312.559 second left to finish this epoch
# batch loss : 0.00158752 -> about 290.511 second left to finish this epoch
# batch loss : 0.00242016 -> about 268.341 second left to finish this epoch
# batch loss : 0.00117773 -> about 246.258 second left to finish this epoch
# batch loss : 0.00260125 -> about 224.289 second left to finish this epoch
# batch loss : 0.00310057 -> about 202.279 second left to finish this epoch
# batch loss : 0.000821533 -> about 180.244 second left to finish this epoch
# batch loss : 0.00280093 -> about 158.232 second left to finish this epoch
# batch loss : 0.000591891 -> about 136.187 second left to finish this epoch
# batch loss : 0.00135658 -> about 114.180 second left to finish this epoch
# batch loss : 0.00305807 -> about 92.172 second left to finish this epoch
# batch loss : 0.00221692 -> about 70.158 second left to finish this epoch
# batch loss : 0.0021335 -> about 48.171 second left to finish this epoch
# batch loss : 0.00479874 -> about 26.186 second left to finish this epoch
# batch loss : 0.00609186 -> about 4.181 second left to finish this epoch
# ('current epoch : 16', ', current train loss : 0.00242960977994')
# batch loss : 0.00150756 -> about 508.829 second left to finish this epoch
# batch loss : 0.00173664 -> about 509.417 second left to finish this epoch
# batch loss : 0.000686366 -> about 488.426 second left to finish this epoch
# batch loss : 0.000755034 -> about 466.209 second left to finish this epoch
# batch loss : 0.00213613 -> about 443.934 second left to finish this epoch
# batch loss : 0.00190773 -> about 421.503 second left to finish this epoch
# batch loss : 0.00100072 -> about 399.440 second left to finish this epoch
# batch loss : 0.00360838 -> about 377.466 second left to finish this epoch
# batch loss : 0.00106808 -> about 355.590 second left to finish this epoch
# batch loss : 0.00244396 -> about 333.445 second left to finish this epoch
# batch loss : 0.000868487 -> about 311.688 second left to finish this epoch
# batch loss : 0.00178008 -> about 289.759 second left to finish this epoch
# batch loss : 0.00152809 -> about 267.810 second left to finish this epoch
# batch loss : 0.00341417 -> about 245.905 second left to finish this epoch
# batch loss : 0.00119593 -> about 223.930 second left to finish this epoch
# batch loss : 0.00117937 -> about 201.948 second left to finish this epoch
# batch loss : 0.00165027 -> about 180.032 second left to finish this epoch
# batch loss : 0.00157318 -> about 155.550 second left to finish this epoch
# batch loss : 0.00435506 -> about 131.588 second left to finish this epoch
# batch loss : 0.00532418 -> about 108.599 second left to finish this epoch
# batch loss : 0.00441243 -> about 87.151 second left to finish this epoch
# batch loss : 0.000686271 -> about 65.452 second left to finish this epoch
# batch loss : 0.00530515 -> about 44.373 second left to finish this epoch
# batch loss : 0.00346629 -> about 23.833 second left to finish this epoch
# batch loss : 0.000919706 -> about 3.764 second left to finish this epoch
# ('current epoch : 17', ', current train loss : 0.00212790138834')
# batch loss : 0.00332939 -> about 359.655 second left to finish this epoch
# batch loss : 0.000971858 -> about 479.941 second left to finish this epoch
# batch loss : 0.000385616 -> about 473.399 second left to finish this epoch
# batch loss : 0.000791041 -> about 455.677 second left to finish this epoch
# batch loss : 0.00215612 -> about 437.611 second left to finish this epoch
# batch loss : 0.00084535 -> about 417.052 second left to finish this epoch
# batch loss : 0.000845772 -> about 395.764 second left to finish this epoch
# batch loss : 0.00471846 -> about 374.341 second left to finish this epoch
# batch loss : 0.00267353 -> about 353.181 second left to finish this epoch
# batch loss : 0.000774498 -> about 331.635 second left to finish this epoch
# batch loss : 0.00222605 -> about 310.039 second left to finish this epoch
# batch loss : 0.00455818 -> about 288.403 second left to finish this epoch
# batch loss : 0.000527716 -> about 266.636 second left to finish this epoch
# batch loss : 0.0007826 -> about 242.938 second left to finish this epoch
# batch loss : 0.000941448 -> about 216.251 second left to finish this epoch
# batch loss : 0.00071534 -> about 191.326 second left to finish this epoch
# batch loss : 0.00357318 -> about 167.479 second left to finish this epoch
# batch loss : 0.00242748 -> about 147.672 second left to finish this epoch
# batch loss : 0.000542222 -> about 127.617 second left to finish this epoch
# batch loss : 0.00143081 -> about 107.333 second left to finish this epoch
# batch loss : 0.00153874 -> about 86.901 second left to finish this epoch
# batch loss : 0.000515 -> about 66.339 second left to finish this epoch
# batch loss : 0.00379736 -> about 45.659 second left to finish this epoch
# batch loss : 0.00183137 -> about 24.866 second left to finish this epoch
# batch loss : 0.00291549 -> about 3.979 second left to finish this epoch
# ('current epoch : 18', ', current train loss : 0.0018856872124')
# batch loss : 0.000418953 -> about 503.174 second left to finish this epoch
# batch loss : 0.000863916 -> about 511.207 second left to finish this epoch
# batch loss : 0.00116081 -> about 488.517 second left to finish this epoch
# batch loss : 0.00287544 -> about 466.613 second left to finish this epoch
# batch loss : 0.000752931 -> about 444.193 second left to finish this epoch
# batch loss : 0.000656435 -> about 422.030 second left to finish this epoch
# batch loss : 0.00217086 -> about 400.667 second left to finish this epoch
# batch loss : 0.000778821 -> about 378.549 second left to finish this epoch
# batch loss : 0.000531324 -> about 356.536 second left to finish this epoch
# batch loss : 0.000833267 -> about 334.493 second left to finish this epoch
# batch loss : 0.000780622 -> about 312.445 second left to finish this epoch
# batch loss : 0.000832526 -> about 290.388 second left to finish this epoch
# batch loss : 0.000402622 -> about 268.347 second left to finish this epoch
# batch loss : 0.0010985 -> about 246.536 second left to finish this epoch
# batch loss : 0.00343769 -> about 224.458 second left to finish this epoch
# batch loss : 0.00087179 -> about 202.421 second left to finish this epoch
# batch loss : 0.000696526 -> about 180.372 second left to finish this epoch
# batch loss : 0.00171426 -> about 158.338 second left to finish this epoch
# batch loss : 0.00130945 -> about 136.293 second left to finish this epoch
# batch loss : 0.000728509 -> about 114.308 second left to finish this epoch
# batch loss : 0.00069115 -> about 92.321 second left to finish this epoch
# batch loss : 0.000555978 -> about 70.305 second left to finish this epoch
# batch loss : 0.000467542 -> about 48.260 second left to finish this epoch
# batch loss : 0.00113811 -> about 26.225 second left to finish this epoch
# batch loss : 0.00340412 -> about 4.189 second left to finish this epoch
# ('current epoch : 19', ', current train loss : 0.00168061341002')
# batch loss : 0.00536509 -> about 511.568 second left to finish this epoch
# batch loss : 0.000372033 -> about 509.703 second left to finish this epoch
# batch loss : 0.00105567 -> about 487.587 second left to finish this epoch
# batch loss : 0.0023702 -> about 465.833 second left to finish this epoch
# batch loss : 0.000462248 -> about 443.888 second left to finish this epoch
# batch loss : 0.00276116 -> about 422.416 second left to finish this epoch
# batch loss : 0.00336637 -> about 400.417 second left to finish this epoch
# batch loss : 0.00212793 -> about 378.327 second left to finish this epoch
# batch loss : 0.00118576 -> about 356.190 second left to finish this epoch
# batch loss : 0.000680499 -> about 328.516 second left to finish this epoch
# batch loss : 0.00174554 -> about 307.286 second left to finish this epoch
# batch loss : 0.00132267 -> about 286.029 second left to finish this epoch
# batch loss : 0.00120842 -> about 264.558 second left to finish this epoch
# batch loss : 0.000563788 -> about 243.034 second left to finish this epoch
# batch loss : 0.000337912 -> about 221.450 second left to finish this epoch
# batch loss : 0.000805442 -> about 199.819 second left to finish this epoch
# batch loss : 0.000839856 -> about 178.189 second left to finish this epoch
# batch loss : 0.00212605 -> about 156.501 second left to finish this epoch
# batch loss : 0.00272539 -> about 134.800 second left to finish this epoch
# batch loss : 0.00174502 -> about 113.076 second left to finish this epoch
# batch loss : 0.000481438 -> about 91.322 second left to finish this epoch
# batch loss : 0.00140863 -> about 69.538 second left to finish this epoch
# batch loss : 0.00321331 -> about 47.746 second left to finish this epoch
# batch loss : 0.00376495 -> about 25.949 second left to finish this epoch
# batch loss : 0.00103703 -> about 4.143 second left to finish this epoch
# ('current epoch : 20', ', current train loss : 0.0015267530434')
# Model saved in file : ./trained_HGN/model.ckpt-20
# batch loss : 0.00185745 -> about 564.421 second left to finish this epoch
# batch loss : 0.000401853 -> about 510.801 second left to finish this epoch
# batch loss : 0.000927543 -> about 487.762 second left to finish this epoch
# batch loss : 0.000500545 -> about 465.033 second left to finish this epoch
# batch loss : 0.000505532 -> about 443.046 second left to finish this epoch
# batch loss : 0.000777153 -> about 421.219 second left to finish this epoch
# batch loss : 0.00146823 -> about 399.140 second left to finish this epoch
# batch loss : 0.000870899 -> about 377.077 second left to finish this epoch
# batch loss : 0.000404372 -> about 355.055 second left to finish this epoch
# batch loss : 0.000579016 -> about 333.175 second left to finish this epoch
# batch loss : 0.00101745 -> about 311.154 second left to finish this epoch
# batch loss : 0.000454245 -> about 289.201 second left to finish this epoch
# batch loss : 0.000917251 -> about 267.306 second left to finish this epoch
# batch loss : 0.000653398 -> about 245.368 second left to finish this epoch
# batch loss : 0.000350048 -> about 223.431 second left to finish this epoch
# batch loss : 0.000478529 -> about 201.490 second left to finish this epoch
# batch loss : 0.000371141 -> about 179.550 second left to finish this epoch
# batch loss : 0.000601284 -> about 157.643 second left to finish this epoch
# batch loss : 0.00169497 -> about 135.730 second left to finish this epoch
# batch loss : 0.000503041 -> about 113.785 second left to finish this epoch
# batch loss : 0.000483888 -> about 91.859 second left to finish this epoch
# batch loss : 0.00286194 -> about 69.959 second left to finish this epoch
# batch loss : 0.00196168 -> about 48.035 second left to finish this epoch
# batch loss : 0.000737637 -> about 26.104 second left to finish this epoch
# batch loss : 0.00300187 -> about 4.168 second left to finish this epoch
# ('current epoch : 21', ', current train loss : 0.0013942813882')
# batch loss : 0.00370837 -> about 539.788 second left to finish this epoch
# batch loss : 0.000443302 -> about 509.162 second left to finish this epoch
# batch loss : 0.000520461 -> about 487.780 second left to finish this epoch
# batch loss : 0.000438601 -> about 465.531 second left to finish this epoch
# batch loss : 0.000746141 -> about 443.677 second left to finish this epoch
# batch loss : 0.00204627 -> about 421.538 second left to finish this epoch
# batch loss : 0.00311066 -> about 399.452 second left to finish this epoch
# batch loss : 0.000711213 -> about 377.404 second left to finish this epoch
# batch loss : 0.000300287 -> about 355.468 second left to finish this epoch
# batch loss : 0.00119086 -> about 333.466 second left to finish this epoch
# batch loss : 0.00349154 -> about 311.347 second left to finish this epoch
# batch loss : 0.000563027 -> about 289.347 second left to finish this epoch
# batch loss : 0.000516673 -> about 267.373 second left to finish this epoch
# batch loss : 0.00220784 -> about 245.454 second left to finish this epoch
# batch loss : 0.000399048 -> about 223.552 second left to finish this epoch
# batch loss : 0.000339345 -> about 201.629 second left to finish this epoch
# batch loss : 0.00200955 -> about 179.667 second left to finish this epoch
# batch loss : 0.00321016 -> about 157.728 second left to finish this epoch
# batch loss : 0.000759795 -> about 135.798 second left to finish this epoch
# batch loss : 0.000666622 -> about 113.846 second left to finish this epoch
# batch loss : 0.00312336 -> about 91.922 second left to finish this epoch
# batch loss : 0.00391254 -> about 69.989 second left to finish this epoch
# batch loss : 0.00329896 -> about 48.046 second left to finish this epoch
# batch loss : 0.00330615 -> about 26.112 second left to finish this epoch
# batch loss : 0.000968544 -> about 4.169 second left to finish this epoch
# ('current epoch : 22', ', current train loss : 0.00128301926209')
# batch loss : 0.000395837 -> about 536.326 second left to finish this epoch
# batch loss : 0.00142898 -> about 508.580 second left to finish this epoch
# batch loss : 0.000687133 -> about 486.157 second left to finish this epoch
# batch loss : 0.000778268 -> about 464.556 second left to finish this epoch
# batch loss : 0.000690238 -> about 442.837 second left to finish this epoch
# batch loss : 0.000604292 -> about 421.002 second left to finish this epoch
# batch loss : 0.000300156 -> about 398.826 second left to finish this epoch
# batch loss : 0.00107139 -> about 376.939 second left to finish this epoch
# batch loss : 0.000365824 -> about 354.816 second left to finish this epoch
# batch loss : 0.000684581 -> about 332.912 second left to finish this epoch
# batch loss : 0.000677276 -> about 310.936 second left to finish this epoch
# batch loss : 0.000540452 -> about 289.201 second left to finish this epoch
# batch loss : 0.000419679 -> about 267.204 second left to finish this epoch
# batch loss : 0.000783867 -> about 245.265 second left to finish this epoch
# batch loss : 0.000543684 -> about 223.371 second left to finish this epoch
# batch loss : 0.00057642 -> about 201.480 second left to finish this epoch
# batch loss : 0.000557469 -> about 179.578 second left to finish this epoch
# batch loss : 0.00113721 -> about 157.649 second left to finish this epoch
# batch loss : 0.000512895 -> about 135.715 second left to finish this epoch
# batch loss : 0.0010082 -> about 113.794 second left to finish this epoch
# batch loss : 0.00125185 -> about 91.870 second left to finish this epoch
# batch loss : 0.00482347 -> about 69.950 second left to finish this epoch
# batch loss : 0.00177302 -> about 48.023 second left to finish this epoch
# batch loss : 0.000856895 -> about 26.092 second left to finish this epoch
# batch loss : 0.00076176 -> about 4.166 second left to finish this epoch
# ('current epoch : 23', ', current train loss : 0.00116943926716')
# batch loss : 0.000285435 -> about 545.189 second left to finish this epoch
# batch loss : 0.000586521 -> about 508.788 second left to finish this epoch
# batch loss : 0.00326381 -> about 486.283 second left to finish this epoch
# batch loss : 0.000719046 -> about 464.667 second left to finish this epoch
# batch loss : 0.00192954 -> about 442.637 second left to finish this epoch
# batch loss : 0.000511701 -> about 420.689 second left to finish this epoch
# batch loss : 0.00208855 -> about 399.178 second left to finish this epoch
# batch loss : 0.00231604 -> about 377.311 second left to finish this epoch
# batch loss : 0.00147057 -> about 355.744 second left to finish this epoch
# batch loss : 0.000891736 -> about 333.695 second left to finish this epoch
# batch loss : 0.000546228 -> about 311.632 second left to finish this epoch
# batch loss : 0.000616896 -> about 289.707 second left to finish this epoch
# batch loss : 0.000646865 -> about 267.638 second left to finish this epoch
# batch loss : 0.00191401 -> about 245.849 second left to finish this epoch
# batch loss : 0.000508014 -> about 223.838 second left to finish this epoch
# batch loss : 0.000768283 -> about 201.831 second left to finish this epoch
# batch loss : 0.00039054 -> about 179.890 second left to finish this epoch
# batch loss : 0.000648912 -> about 157.921 second left to finish this epoch
# batch loss : 0.000506585 -> about 135.943 second left to finish this epoch
# batch loss : 0.00191044 -> about 113.970 second left to finish this epoch
# batch loss : 0.000508845 -> about 92.005 second left to finish this epoch
# batch loss : 0.000678316 -> about 70.041 second left to finish this epoch
# batch loss : 0.00113618 -> about 48.091 second left to finish this epoch
# batch loss : 0.000567264 -> about 26.129 second left to finish this epoch
# batch loss : 0.000747098 -> about 4.172 second left to finish this epoch
# ('current epoch : 24', ', current train loss : 0.00106647260282')
# batch loss : 0.00337355 -> about 540.487 second left to finish this epoch
# batch loss : 0.000439433 -> about 509.314 second left to finish this epoch
# batch loss : 0.000945784 -> about 486.957 second left to finish this epoch
# batch loss : 0.00202705 -> about 465.362 second left to finish this epoch
# batch loss : 0.00239926 -> about 443.257 second left to finish this epoch
# batch loss : 0.000618165 -> about 421.230 second left to finish this epoch
# batch loss : 0.000943631 -> about 399.468 second left to finish this epoch
# batch loss : 0.000227211 -> about 377.496 second left to finish this epoch
# batch loss : 0.000431567 -> about 355.627 second left to finish this epoch
# batch loss : 0.000742601 -> about 333.553 second left to finish this epoch
# batch loss : 0.000356355 -> about 311.437 second left to finish this epoch
# batch loss : 0.00124524 -> about 289.465 second left to finish this epoch
# batch loss : 0.000445464 -> about 267.496 second left to finish this epoch
# batch loss : 0.000691806 -> about 245.539 second left to finish this epoch
# batch loss : 0.000545933 -> about 223.575 second left to finish this epoch
# batch loss : 0.000689231 -> about 201.667 second left to finish this epoch
# batch loss : 0.00158213 -> about 179.720 second left to finish this epoch
# batch loss : 0.0010071 -> about 157.777 second left to finish this epoch
# batch loss : 0.00046479 -> about 135.832 second left to finish this epoch
# batch loss : 0.000258627 -> about 113.955 second left to finish this epoch
# batch loss : 0.000259039 -> about 91.987 second left to finish this epoch
# batch loss : 0.000628667 -> about 70.032 second left to finish this epoch
# batch loss : 0.000675232 -> about 48.076 second left to finish this epoch
# batch loss : 0.000906376 -> about 26.122 second left to finish this epoch
# batch loss : 0.000491999 -> about 4.170 second left to finish this epoch
# ('current epoch : 25', ', current train loss : 0.000995246196423')
# batch loss : 0.00107649 -> about 511.674 second left to finish this epoch
# ...
# batch loss : 0.000189258 -> about 121.280 second left to finish this epoch
# batch loss : 4.60938e-05 -> about 106.474 second left to finish this epoch
# batch loss : 0.000116401 -> about 91.668 second left to finish this epoch
# batch loss : 3.13063e-05 -> about 76.863 second left to finish this epoch
# batch loss : 4.2867e-05 -> about 62.055 second left to finish this epoch
# batch loss : 4.04995e-05 -> about 47.247 second left to finish this epoch
# batch loss : 4.07299e-05 -> about 32.436 second left to finish this epoch
# batch loss : 6.93641e-05 -> about 17.625 second left to finish this epoch
# batch loss : 3.18264e-05 -> about 2.814 second left to finish this epoch
# ('current epoch : 158', ', current train loss : 5.628553116e-05')
# batch loss : 0.000139049 -> about 356.033 second left to finish this epoch
# batch loss : 6.37433e-05 -> about 343.149 second left to finish this epoch
# batch loss : 2.9025e-05 -> about 328.677 second left to finish this epoch
# batch loss : 8.45352e-05 -> about 313.981 second left to finish this epoch
# batch loss : 3.34732e-05 -> about 299.196 second left to finish this epoch
# batch loss : 3.50467e-05 -> about 284.484 second left to finish this epoch
# batch loss : 5.33712e-05 -> about 269.560 second left to finish this epoch
# batch loss : 2.68199e-05 -> about 254.737 second left to finish this epoch
# batch loss : 4.4041e-05 -> about 239.909 second left to finish this epoch
# batch loss : 3.46591e-05 -> about 225.083 second left to finish this epoch
# batch loss : 3.01476e-05 -> about 210.212 second left to finish this epoch
# batch loss : 5.41564e-05 -> about 195.406 second left to finish this epoch
# batch loss : 3.02156e-05 -> about 180.607 second left to finish this epoch
# batch loss : 4.25876e-05 -> about 165.789 second left to finish this epoch
# batch loss : 2.06749e-05 -> about 150.977 second left to finish this epoch
# batch loss : 3.26459e-05 -> about 136.143 second left to finish this epoch
# batch loss : 0.000111338 -> about 121.320 second left to finish this epoch
# batch loss : 2.41611e-05 -> about 106.505 second left to finish this epoch
# batch loss : 4.22619e-05 -> about 91.692 second left to finish this epoch
# batch loss : 2.76738e-05 -> about 76.871 second left to finish this epoch
# batch loss : 3.80517e-05 -> about 62.061 second left to finish this epoch
# batch loss : 2.64906e-05 -> about 47.253 second left to finish this epoch
# batch loss : 2.67194e-05 -> about 32.440 second left to finish this epoch
# batch loss : 3.65909e-05 -> about 17.627 second left to finish this epoch
# batch loss : 2.78616e-05 -> about 2.815 second left to finish this epoch
# ('current epoch : 159', ', current train loss : 4.8058908033e-05')
# batch loss : 3.31881e-05 -> about 361.769 second left to finish this epoch
# batch loss : 2.15042e-05 -> about 342.836 second left to finish this epoch
# batch loss : 2.49108e-05 -> about 328.231 second left to finish this epoch
# batch loss : 1.873e-05 -> about 313.791 second left to finish this epoch
# batch loss : 2.45714e-05 -> about 299.035 second left to finish this epoch
# batch loss : 1.82268e-05 -> about 284.258 second left to finish this epoch
# batch loss : 3.39564e-05 -> about 269.497 second left to finish this epoch
# batch loss : 4.34225e-05 -> about 254.708 second left to finish this epoch
# batch loss : 4.60987e-05 -> about 239.870 second left to finish this epoch
# batch loss : 2.10218e-05 -> about 225.053 second left to finish this epoch
# batch loss : 2.81095e-05 -> about 210.212 second left to finish this epoch
# batch loss : 1.80546e-05 -> about 195.391 second left to finish this epoch
# batch loss : 2.19871e-05 -> about 180.598 second left to finish this epoch
# batch loss : 2.54187e-05 -> about 165.788 second left to finish this epoch
# batch loss : 1.48575e-05 -> about 150.967 second left to finish this epoch
# batch loss : 2.47751e-05 -> about 136.138 second left to finish this epoch
# batch loss : 2.41313e-05 -> about 121.331 second left to finish this epoch
# batch loss : 2.69283e-05 -> about 106.529 second left to finish this epoch
# batch loss : 2.12642e-05 -> about 91.752 second left to finish this epoch
# batch loss : 3.81947e-05 -> about 76.956 second left to finish this epoch
# batch loss : 2.69355e-05 -> about 62.152 second left to finish this epoch
# batch loss : 2.14854e-05 -> about 47.329 second left to finish this epoch
# batch loss : 2.81332e-05 -> about 32.498 second left to finish this epoch
# batch loss : 1.1445e-05 -> about 17.704 second left to finish this epoch
# batch loss : 1.89175e-05 -> about 2.826 second left to finish this epoch
# ('current epoch : 160', ', current train loss : 3.04889863983e-05')
# Model saved in file : ./trained_HGN/model.ckpt-160
# batch loss : 2.0322e-05 -> about 361.882 second left to finish this epoch
# batch loss : 1.07839e-05 -> about 344.324 second left to finish this epoch
# batch loss : 1.75782e-05 -> about 329.116 second left to finish this epoch
# batch loss : 1.51064e-05 -> about 314.604 second left to finish this epoch
# batch loss : 0.00011922 -> about 299.574 second left to finish this epoch
# batch loss : 9.84777e-05 -> about 284.853 second left to finish this epoch
# batch loss : 5.8256e-05 -> about 270.013 second left to finish this epoch
# batch loss : 2.75883e-05 -> about 255.137 second left to finish this epoch
# batch loss : 3.56801e-05 -> about 240.316 second left to finish this epoch
# batch loss : 3.36802e-05 -> about 225.427 second left to finish this epoch
# batch loss : 6.06013e-05 -> about 210.558 second left to finish this epoch
# batch loss : 4.07691e-05 -> about 195.742 second left to finish this epoch
# batch loss : 4.8121e-05 -> about 180.902 second left to finish this epoch
# batch loss : 3.20317e-05 -> about 166.060 second left to finish this epoch
# batch loss : 5.12081e-05 -> about 151.216 second left to finish this epoch
# batch loss : 3.23115e-05 -> about 136.379 second left to finish this epoch
# batch loss : 2.61407e-05 -> about 121.547 second left to finish this epoch
# batch loss : 3.15896e-05 -> about 106.705 second left to finish this epoch
# batch loss : 8.2675e-05 -> about 91.859 second left to finish this epoch
# batch loss : 6.7349e-05 -> about 77.019 second left to finish this epoch
# batch loss : 3.28819e-05 -> about 62.178 second left to finish this epoch
# batch loss : 3.22755e-05 -> about 47.333 second left to finish this epoch
# batch loss : 2.72942e-05 -> about 32.493 second left to finish this epoch
# batch loss : 7.71803e-05 -> about 17.656 second left to finish this epoch
# batch loss : 1.50763e-05 -> about 2.819 second left to finish this epoch
# ('current epoch : 161', ', current train loss : 5.471546256e-05')
# batch loss : 2.95804e-05 -> about 354.768 second left to finish this epoch
# batch loss : 2.82794e-05 -> about 343.806 second left to finish this epoch
# batch loss : 2.68426e-05 -> about 329.061 second left to finish this epoch
# batch loss : 2.44776e-05 -> about 314.320 second left to finish this epoch
# batch loss : 2.83438e-05 -> about 299.474 second left to finish this epoch
# batch loss : 2.28357e-05 -> about 284.625 second left to finish this epoch
# batch loss : 2.09167e-05 -> about 269.817 second left to finish this epoch
# batch loss : 5.71382e-05 -> about 255.017 second left to finish this epoch
# batch loss : 3.3096e-05 -> about 240.180 second left to finish this epoch
# batch loss : 4.32608e-05 -> about 225.306 second left to finish this epoch
# batch loss : 2.83149e-05 -> about 210.500 second left to finish this epoch
# batch loss : 2.10521e-05 -> about 195.664 second left to finish this epoch
# batch loss : 6.169e-05 -> about 180.849 second left to finish this epoch
# batch loss : 2.41053e-05 -> about 166.025 second left to finish this epoch
# batch loss : 4.12137e-05 -> about 151.200 second left to finish this epoch
# batch loss : 2.46336e-05 -> about 136.351 second left to finish this epoch
# batch loss : 2.58984e-05 -> about 121.514 second left to finish this epoch
# batch loss : 4.70278e-05 -> about 106.680 second left to finish this epoch
# batch loss : 2.67148e-05 -> about 91.844 second left to finish this epoch
# batch loss : 1.53721e-05 -> about 77.007 second left to finish this epoch
# batch loss : 4.03616e-05 -> about 62.173 second left to finish this epoch
# batch loss : 1.90389e-05 -> about 47.333 second left to finish this epoch
# batch loss : 2.73043e-05 -> about 32.498 second left to finish this epoch
# batch loss : 2.69019e-05 -> about 17.659 second left to finish this epoch
# batch loss : 3.41635e-05 -> about 2.820 second left to finish this epoch
# ('current epoch : 162', ', current train loss : 3.97461925034e-05')
# batch loss : 2.04938e-05 -> about 358.314 second left to finish this epoch
# batch loss : 5.24072e-05 -> about 344.332 second left to finish this epoch
# batch loss : 6.49524e-05 -> about 329.272 second left to finish this epoch
# batch loss : 2.41539e-05 -> about 314.433 second left to finish this epoch
# batch loss : 2.30453e-05 -> about 299.551 second left to finish this epoch
# batch loss : 7.62306e-05 -> about 284.755 second left to finish this epoch
# batch loss : 0.000623336 -> about 269.887 second left to finish this epoch
# batch loss : 3.43013e-05 -> about 255.090 second left to finish this epoch
# batch loss : 3.86594e-05 -> about 240.287 second left to finish this epoch
# batch loss : 3.91656e-05 -> about 225.436 second left to finish this epoch
# batch loss : 3.11464e-05 -> about 210.586 second left to finish this epoch
# batch loss : 3.08015e-05 -> about 195.734 second left to finish this epoch
# batch loss : 3.1663e-05 -> about 180.928 second left to finish this epoch
# batch loss : 2.7313e-05 -> about 166.088 second left to finish this epoch
# batch loss : 3.67246e-05 -> about 151.242 second left to finish this epoch
# batch loss : 3.6608e-05 -> about 136.383 second left to finish this epoch
# batch loss : 4.66521e-05 -> about 121.543 second left to finish this epoch
# batch loss : 3.56323e-05 -> about 106.692 second left to finish this epoch
# batch loss : 2.47973e-05 -> about 91.851 second left to finish this epoch
# batch loss : 2.21346e-05 -> about 77.001 second left to finish this epoch
# batch loss : 4.4784e-05 -> about 62.167 second left to finish this epoch
# batch loss : 6.62708e-05 -> about 47.331 second left to finish this epoch
# batch loss : 2.64497e-05 -> about 32.494 second left to finish this epoch
# batch loss : 3.17064e-05 -> about 17.655 second left to finish this epoch
# batch loss : 3.51903e-05 -> about 2.819 second left to finish this epoch
# ('current epoch : 163', ', current train loss : 5.18360525846e-05')
# batch loss : 4.13158e-05 -> about 358.631 second left to finish this epoch
# batch loss : 5.47915e-05 -> about 343.474 second left to finish this epoch
# batch loss : 3.66159e-05 -> about 328.904 second left to finish this epoch
# batch loss : 1.73853e-05 -> about 314.202 second left to finish this epoch
# batch loss : 3.2778e-05 -> about 299.445 second left to finish this epoch
# batch loss : 0.000113772 -> about 284.660 second left to finish this epoch
# batch loss : 6.36872e-05 -> about 269.881 second left to finish this epoch
# batch loss : 3.41767e-05 -> about 255.052 second left to finish this epoch
# batch loss : 3.40971e-05 -> about 240.192 second left to finish this epoch
# batch loss : 4.90649e-05 -> about 225.308 second left to finish this epoch
# batch loss : 3.49148e-05 -> about 210.475 second left to finish this epoch
# batch loss : 3.17453e-05 -> about 195.647 second left to finish this epoch
# batch loss : 3.27342e-05 -> about 180.820 second left to finish this epoch
# batch loss : 3.35996e-05 -> about 165.993 second left to finish this epoch
# batch loss : 1.78411e-05 -> about 151.147 second left to finish this epoch
# batch loss : 3.00435e-05 -> about 136.316 second left to finish this epoch
# batch loss : 3.39666e-05 -> about 121.498 second left to finish this epoch
# batch loss : 2.41064e-05 -> about 106.664 second left to finish this epoch
# batch loss : 1.93162e-05 -> about 91.837 second left to finish this epoch
# batch loss : 2.00412e-05 -> about 77.001 second left to finish this epoch
# batch loss : 2.61715e-05 -> about 62.164 second left to finish this epoch
# batch loss : 3.00085e-05 -> about 47.322 second left to finish this epoch
# batch loss : 2.05166e-05 -> about 32.486 second left to finish this epoch
# batch loss : 2.5229e-05 -> about 17.651 second left to finish this epoch
# batch loss : 3.6319e-05 -> about 2.818 second left to finish this epoch
# ('current epoch : 164', ', current train loss : 4.38328860744e-05')
# batch loss : 2.84459e-05 -> about 361.051 second left to finish this epoch
# batch loss : 2.0354e-05 -> about 344.108 second left to finish this epoch
# batch loss : 2.63959e-05 -> about 329.125 second left to finish this epoch
# batch loss : 6.88616e-05 -> about 314.468 second left to finish this epoch
# batch loss : 4.67425e-05 -> about 299.515 second left to finish this epoch
# batch loss : 0.000148028 -> about 284.608 second left to finish this epoch
# batch loss : 3.5078e-05 -> about 269.781 second left to finish this epoch
# batch loss : 3.7868e-05 -> about 254.904 second left to finish this epoch
# batch loss : 2.67603e-05 -> about 240.099 second left to finish this epoch
# batch loss : 3.46699e-05 -> about 225.385 second left to finish this epoch
# batch loss : 2.876e-05 -> about 211.124 second left to finish this epoch
# batch loss : 3.51492e-05 -> about 196.450 second left to finish this epoch
# batch loss : 5.47211e-05 -> about 181.856 second left to finish this epoch
# batch loss : 1.94889e-05 -> about 166.860 second left to finish this epoch
# batch loss : 4.50334e-05 -> about 151.912 second left to finish this epoch
# batch loss : 5.66146e-05 -> about 136.958 second left to finish this epoch
# batch loss : 3.49188e-05 -> about 122.035 second left to finish this epoch
# batch loss : 4.17612e-05 -> about 107.112 second left to finish this epoch
# batch loss : 3.93264e-05 -> about 92.190 second left to finish this epoch
# batch loss : 4.86316e-05 -> about 77.287 second left to finish this epoch
# batch loss : 6.53427e-05 -> about 62.387 second left to finish this epoch
# batch loss : 2.15079e-05 -> about 47.490 second left to finish this epoch
# batch loss : 4.76719e-05 -> about 32.601 second left to finish this epoch
# batch loss : 3.44094e-05 -> about 17.713 second left to finish this epoch
# batch loss : 5.52512e-05 -> about 2.828 second left to finish this epoch
# ('current epoch : 165', ', current train loss : 5.70975978311e-05')
# batch loss : 2.3407e-05 -> about 354.558 second left to finish this epoch
# batch loss : 2.85523e-05 -> about 343.928 second left to finish this epoch
# batch loss : 5.97509e-05 -> about 329.128 second left to finish this epoch
# batch loss : 4.70118e-05 -> about 314.368 second left to finish this epoch
# batch loss : 5.09921e-05 -> about 299.632 second left to finish this epoch
# batch loss : 5.94341e-05 -> about 284.815 second left to finish this epoch
# batch loss : 4.2416e-05 -> about 270.044 second left to finish this epoch
# batch loss : 3.24893e-05 -> about 255.186 second left to finish this epoch
# batch loss : 7.32792e-05 -> about 240.328 second left to finish this epoch
# batch loss : 5.93184e-05 -> about 225.508 second left to finish this epoch
# batch loss : 4.55056e-05 -> about 210.668 second left to finish this epoch
# batch loss : 3.12626e-05 -> about 195.798 second left to finish this epoch
# batch loss : 2.23779e-05 -> about 180.954 second left to finish this epoch
# batch loss : 7.83984e-05 -> about 166.109 second left to finish this epoch
# batch loss : 5.94767e-05 -> about 151.274 second left to finish this epoch
# batch loss : 4.55838e-05 -> about 136.425 second left to finish this epoch
# batch loss : 2.45175e-05 -> about 121.586 second left to finish this epoch
# batch loss : 1.6806e-05 -> about 106.729 second left to finish this epoch
# batch loss : 7.11704e-05 -> about 91.885 second left to finish this epoch
# batch loss : 3.19381e-05 -> about 77.047 second left to finish this epoch
# batch loss : 4.31021e-05 -> about 62.200 second left to finish this epoch
# batch loss : 3.21531e-05 -> about 47.359 second left to finish this epoch
